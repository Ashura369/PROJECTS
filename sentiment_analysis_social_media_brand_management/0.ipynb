# %%
import pandas as pd

# %%
import pickle

# Load the model back
with open('D:\THE CODE\PROJECTS\sentiment_analysis_social_media_brand_management\df_1.kl', 'rb') as f:
    df = pickle.load(f)
# Out:
# <>:4: SyntaxWarning: invalid escape sequence '\T'
# <>:4: SyntaxWarning: invalid escape sequence '\T'
# C:\Users\ashura\AppData\Local\Temp\ipykernel_13268\3244706676.py:4: SyntaxWarning: invalid escape sequence '\T'
#   with open('D:\THE CODE\PROJECTS\sentiment_analysis_social_media_brand_management\df_1.kl', 'rb') as f:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 5
#       1 import pickle
#       2
#       3 # Load the model back
#       4 with open('D:\THE CODE\PROJECTS\sentiment_analysis_social_media_brand_management\df_1.kl', 'rb') as f:
# ----> 5     df = pickle.load(f)
#
# ModuleNotFoundError: No module named 'cudf'
